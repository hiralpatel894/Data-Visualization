# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import plotly.tools as tls

# %%
mapbox_access_token = 'pk.eyJ1IjoiamFncnV0aXBhdGVsIiwiYSI6ImNqa2JvODVoZzB0ZG4zcWxpa3hhMDM0Y3QifQ.tZMJkIBa_I6xGMHtHxsFhQ'

# %%
location_data = pd.read_csv("location1.csv")
location_data
# Out:
#    Name  Gender                                    Address  Year
# 0   abc  Female          401 Sunset Ave Windsor ON N9B 3P4  2018
# 1   def    Male    157 University Ave W Windsor ON N9A 5P4  2017
# 2   xyz    Male    2300 Huron Church Rd Windsor ON N9E 3S6  2016
# 3   res  Female      825 Riverside Dr W Windsor ON N9A 5K9  2015
# 4   tyu  Female       1530 Langlois Ave Windsor ON N8X 4M2  2018
# 5   aaa    Male           729 Caron Ave Windsor ON N9A 5B8  2017
# 6   bbb  Female          1444 Ottawa St Windsor ON N8X 2G1  2018
# 7   ccc  Female        3195 Sandwich St Windsor ON N9C 1A7  2017
# 8   ddd  Female         80 Chatham St E Windsor ON N9A 2W1  2018
# 9   eee  Female  350 City Hall Square E Windsor ON N9A 6S1  2016
# 10  fff  Female      400 City Hall Sq E Windsor ON N9A 7K6  2015
# 11  ggg  Female      201 Riverside Dr W Windsor ON N9A 5K4  2018
# 12  hhh  Female       546 Ouellette Ave Windsor ON N9A 1B3  2018

# %%
import googlemaps
gmaps_key = googlemaps.Client(key = "AIzaSyC2sR6dggRoaAVMXZ6DZxH6zvh2OtetUtk")
location_data['lat'] = None
location_data['lon'] = None
for i in range(0,len(location_data)):
    geocode_result = gmaps_key.geocode(location_data.iat[i,2])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        location_data.iat[i,location_data.columns.get_loc('lat')] = lat
        location_data.iat[i,location_data.columns.get_loc('lon')] = lon

    except:
        lat = None
        lon = None
        
location_data
# Out:
#    Name  Gender                                    Address  Year      lat  \
# 0   abc  Female          401 Sunset Ave Windsor ON N9B 3P4  2018  42.3077
# 1   def    Male    157 University Ave W Windsor ON N9A 5P4  2017   42.317
# 2   xyz    Male    2300 Huron Church Rd Windsor ON N9E 3S6  2016  42.2737
# 3   res  Female      825 Riverside Dr W Windsor ON N9A 5K9  2015  42.3167
# 4   tyu  Female       1530 Langlois Ave Windsor ON N8X 4M2  2018  42.3047
# 5   aaa    Male           729 Caron Ave Windsor ON N9A 5B8  2017    42.31
# 6   bbb  Female          1444 Ottawa St Windsor ON N8X 2G1  2018  42.3105
# 7   ccc  Female        3195 Sandwich St Windsor ON N9C 1A7  2017  42.3022
# 8   ddd  Female         80 Chatham St E Windsor ON N9A 2W1  2018  42.3187
# 9   eee  Female  350 City Hall Square E Windsor ON N9A 6S1  2016  42.3174
# 10  fff  Female      400 City Hall Sq E Windsor ON N9A 7K6  2015  42.3175
# 11  ggg  Female      201 Riverside Dr W Windsor ON N9A 5K4  2018  42.3188
# ...

# %%
years = location_data["Year"].unique()
years = list(sorted(years.astype(str)))
    
data = [
    go.Scattermapbox(
        lat=list(location_data["lat"]),
        lon=list(location_data["lon"]),
        mode='markers',
        marker=dict(
            size=10,
            autocolorscale = False,
        ),
        text= list('Name: '+location_data['Name'].astype(str)
                    +', Gender: '+location_data['Gender'].astype(str)
                    +', Address: '+location_data['Address'].astype(str)
                    +', Year: '+location_data['Year'].astype(str)),
    )
]

# %%
years = location_data["Year"].unique()
years = list(sorted(years.astype(str)))
mapbox_access_token = 'pk.eyJ1IjoiamFncnV0aXBhdGVsIiwiYSI6ImNqa2JvODVoZzB0ZG4zcWxpa3hhMDM0Y3QifQ.tZMJkIBa_I6xGMHtHxsFhQ'
steps = []
for i in range(len(years)):
    step = dict(
        method = 'restyle',  
        args = ['visible', [False] * len(years)],
        label=years[i]
    )
    step['args'][1][i] = True # Toggle i'th trace to "visible"
    steps.append(step)

sliders = [dict(
    active = 10,
    currentvalue = {"prefix": "Year: "},
    pad = {"t": 1},
    steps = steps
)]

layout = dict(sliders=sliders,title = "Patient's data",
              mapbox=dict(
               accesstoken=mapbox_access_token,
                center=dict(
                    lat=42.3077	,
                    lon=-83.0684
                ),
                zoom=12
    ),
)

fig = dict(data=data, layout=layout)

py.iplot(fig, filename="Patient's data")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagruti.patel199320/11.embed" height="525px" width="100%"></iframe>
